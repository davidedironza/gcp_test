# %% [markdown]
# http://airflow.apache.org/tutorial.html

# %%
BUCKET = "europe-west1-bindexis-envir-d65b4ff0-bucket"

# %%
import os
os.environ['BUCKET'] = BUCKET

# %%
# %%writefile dag_bindexis_dataload.py

"""
Code that goes along with the Airflow tutorial located at:
https://github.com/apache/airflow/blob/master/airflow/example_dags/tutorial.py
"""

from __future__ import print_function

import datetime
import pytz

from airflow import models
from airflow.models import Variable
from airflow.operators import bash_operator
from airflow.operators import python_operator
from airflow.operators import email_operator
#from airflow.operators import docker_operator

# Installing a local Python library
from dependencies import def_bindexis_dataload

default_dag_args = {
    # The start_date describes when a DAG is valid / can be run. Set this to a
    # fixed point in time rather than dynamically, since it is evaluated every
    # time a DAG is parsed. See:
    # https://airflow.apache.org/faq.html#what-s-the-deal-with-start-date
    'owner': 'CI',
    'depends_on_past': False,
    'start_date': pytz.utc.localize(datetime.datetime(2019, 5, 9, 10, 0)).astimezone(pytz.timezone("Europe/Zurich")),
    'end_date': datetime.datetime(2019, 5, 20),
    'email': ['davide.dironza@axa.ch'],
    'email_on_failure': False,
    'email_on_retry': False,
    'retries': 0, # general retries, can be changed by every task
    'retry_delay': datetime.timedelta(minutes=5),
    # 'queue': 'bash_queue',
    # 'pool': 'backfill',
    # 'priority_weight': 10,
}

# Define a DAG (directed acyclic graph) of tasks.
# Any task you create within the context manager is automatically added to the
# DAG object.
with models.DAG(
        'bindexis_end2end',
        schedule_interval=datetime.timedelta(days=1), # or in cron Format
        default_args=default_dag_args) as dag:

    # An instance of an operator is called a task. In this case, the
    # hello_python task calls the "greeting" Python function.
    bindexis_python = python_operator.PythonOperator(
        task_id='bindexis-dataload-start',
        python_callable=def_bindexis_dataload.bindexis_dataload,
        op_kwargs={'user_bindexis': Variable.get("user_bindexis"),
                    'pw_bindexis': Variable.get("password_bindexis")},
        retries=2)

    # Likewise, the goodbye_bash task calls a Bash script.
    end_bash = bash_operator.BashOperator(
        task_id='bindexis-end',
        bash_command='echo bindexis-dataload-end.')

    # Define the order in which the tasks complete by using the >> and <<
    # operators. In this example, bindexis_python executes before end_bash.
    bindexis_python >> end_bash


# Send email confirmation
#email_summary = EmailOperator(
#    task_id='email_summary',
#    to=models.Variable.get('email'),
#    subject='ERROR: Bindexis Dataload and Trigger',
#    html_content="""
#    Bindexis Dataload fails.
#    Error: {ERROR_FROM_LOG}.
#    """.format(
#        ERROR_FROM_LOG=(
#            'CAN WE ACCESS THE LOGGING TEXT TO SHOW???'
#        )),
#    dag=dag)
# Out:
# Overwriting dag_bindexis_dataload.py

# %%
# %%bash
# gsutil cp -r dependencies gs://${BUCKET}/dags
# Out:
# Copying file://dependencies/def_bindexis_dataload.py [Content-Type=text/x-python]...
# Copying file://dependencies/__init__.py [Content-Type=text/x-python]...
# Copying file://dependencies/__pycache__/__init__.cpython-35.pyc [Content-Type=application/x-python-code]...
# Copying file://dependencies/__pycache__/def_bindexis_dataload.cpython-35.pyc [Content-Type=application/x-python-code]...
# - [4 files][ 29.7 KiB/ 29.7 KiB]
# ==> NOTE: You are performing a sequence of gsutil operations that may
# run significantly faster if you instead use gsutil -m cp ... Please
# see the -m section under "gsutil help options" for further information
# about when gsutil -m can be advantageous.
#
# Copying file://dependencies/.ipynb_checkpoints/__init__-checkpoint.py [Content-Type=text/x-python]...
# Copying file://dependencies/.ipynb_checkpoints/def_bindexis_dataload-checkpoint.py [Content-Type=text/x-python]...
# - [6 files][ 47.2 KiB/ 47.2 KiB]
# Operation completed over 6 objects/47.2 KiB.

# %%
# %%bash
# gsutil cp dag_bindexis_dataload.py gs://${BUCKET}/dags
# Out:
# Copying file://dag_bindexis_dataload.py [Content-Type=text/x-python]...
# / [1 files][  2.8 KiB/  2.8 KiB]
# Operation completed over 1 objects/2.8 KiB.

# %%
# %%writefile simple_greeting.py

from __future__ import print_function

import datetime

from airflow import models
from airflow.operators import bash_operator
from airflow.operators import python_operator


default_dag_args = {
    # The start_date describes when a DAG is valid / can be run. Set this to a
    # fixed point in time rather than dynamically, since it is evaluated every
    # time a DAG is parsed. See:
    # https://airflow.apache.org/faq.html#what-s-the-deal-with-start-date
    'start_date': datetime.datetime(2019, 4, 28),
    'end_date': datetime.datetime(2019, 5, 5)
}

# Define a DAG (directed acyclic graph) of tasks.
# Any task you create within the context manager is automatically added to the
# DAG object.
with models.DAG(
        'composer_sample_simple_greeting2',
        schedule_interval=datetime.timedelta(days=1),
        default_args=default_dag_args) as dag:
    def greeting():
        import logging
        logging.info('Hello World!')

    # An instance of an operator is called a task. In this case, the
    # hello_python task calls the "greeting" Python function.
    hello_python = python_operator.PythonOperator(
        task_id='hello',
        python_callable=greeting)

    # Likewise, the goodbye_bash task calls a Bash script.
    goodbye_bash = bash_operator.BashOperator(
        task_id='bye',
        bash_command='echo Goodbye.')

    # Define the order in which the tasks complete by using the >> and <<
    # operators. In this example, hello_python executes before goodbye_bash.
    hello_python >> goodbye_bash
# Out:
# Overwriting simple_greeting.py

# %%
# %%bash
# gsutil cp simple_greeting.py gs://${BUCKET}/dags
# Out:
# Copying file://simple_greeting.py [Content-Type=text/x-python]...
# / [1 files][  1.5 KiB/  1.5 KiB]
# Operation completed over 1 objects/1.5 KiB.

# %%
pip install apache-airflow
# Out:
# Collecting apache-airflow
#   Downloading https://files.pythonhosted.org/packages/07/2d/6267bc5fa85d773ca0ec8ed8981425af789ba95bc7884f33e845b663446e/apache_airflow-1.10.3-py2.py3-none-any.whl (5.8MB)
#     100% |████████████████████████████████| 5.8MB 207kB/s
# Collecting flask<2.0,>=1.0 (from apache-airflow)
#   Downloading https://files.pythonhosted.org/packages/7f/e7/08578774ed4536d3242b14dacb4696386634607af824ea997202cd0edb4b/Flask-1.0.2-py2.py3-none-any.whl (91kB)
#     100% |████████████████████████████████| 92kB 10.0MB/s
# Collecting tenacity==4.12.0 (from apache-airflow)
#   Downloading https://files.pythonhosted.org/packages/75/1b/46a6a7b7c2b16811665ea09b7e63e7e6b7f9b5dedf2d0ba67e029668403c/tenacity-4.12.0-py2.py3-none-any.whl
# Collecting funcsigs==1.0.0 (from apache-airflow)
#   Downloading https://files.pythonhosted.org/packages/09/8d/17528625d12ca90651dd1f7958fd0d32b23b15f2197023372669fd683321/funcsigs-1.0.0-py2.py3-none-any.whl
# Collecting configparser<3.6.0,>=3.5.0 (from apache-airflow)
#   Downloading https://files.pythonhosted.org/packages/55/c0/e0206081eaad646c6f5e2dc266edf457110d9031b363518d3264880e675d/configparser-3.5.3-py3-none-any.whl
# Collecting jinja2<=2.10.0,>=2.7.3 (from apache-airflow)
#   Downloading https://files.pythonhosted.org/packages/7f/ff/ae64bacdfc95f27a016a7bed8e8686763ba4d277a78ca76f32659220a731/Jinja2-2.10-py2.py3-none-any.whl (126kB)
#     100% |████████████████████████████████| 133kB 6.8MB/s
# Collecting flask-appbuilder==1.12.3 (from apache-airflow)
#   Downloading https://files.pythonhosted.org/packages/3a/b0/edb3e54241203266222c4863ae6eb30fd49f5d331a117b61f1801e8124da/Flask-AppBuilder-1.12.3.tar.gz (2.3MB)
#     100% |████████████████████████████████| 2.3MB 529kB/s
# Collecting flask-swagger==0.2.13 (from apache-airflow)
#   Downloading https://files.pythonhosted.org/packages/68/97/4e31ac3dc4a44a4b7487eab8404a68c871b57a15811e189862d0bf0c5b55/flask-swagger-0.2.13.tar.gz
# Collecting future<0.17,>=0.16.0 (from apache-airflow)
#   Downloading https://files.pythonhosted.org/packages/00/2b/8d082ddfed935f3608cc61140df6dcbf0edea1bc3ab52fb6c29ae3e81e85/future-0.16.0.tar.gz (824kB)
#     100% |████████████████████████████████| 829kB 1.6MB/s
# Collecting python-daemon<2.2,>=2.1.1 (from apache-airflow)
#   Downloading https://files.pythonhosted.org/packages/f4/59/816004688f8e8602526553cd96226f34657ce4a86daa2240c3eebb0568a3/python_daemon-2.1.2-py2.py3-none-any.whl
# Collecting text-unidecode==1.2 (from apache-airflow)
#   Downloading https://files.pythonhosted.org/packages/79/42/d717cc2b4520fb09e45b344b1b0b4e81aa672001dd128c180fabc655c341/text_unidecode-1.2-py2.py3-none-any.whl (77kB)
#     100% |████████████████████████████████| 81kB 10.1MB/s
# Collecting alembic<1.0,>=0.9 (from apache-airflow)
#   Downloading https://files.pythonhosted.org/packages/98/dd/fce24f825880875f073c0f9169a9e629ae1d9ea722ebb944153a0b68ab46/alembic-0.9.10.tar.gz (1.0MB)
#     100% |████████████████████████████████| 1.0MB 1.3MB/s
# Collecting sqlalchemy<1.3.0,>=1.1.15 (from apache-airflow)
#   Downloading https://files.pythonhosted.org/packages/f9/67/d07cf7ac7e6dd0bc55ba62816753f86d7c558107104ca915e730c9ec2512/SQLAlchemy-1.2.19.tar.gz (5.7MB)
#     100% |████████████████████████████████| 5.7MB 210kB/s
# Collecting markdown<3.0,>=2.5.2 (from apache-airflow)
#   Downloading https://files.pythonhosted.org/packages/6d/7d/488b90f470b96531a3f5788cf12a93332f543dbab13c423a5e7ce96a0493/Markdown-2.6.11-py2.py3-none-any.whl (78kB)
#     100% |████████████████████████████████| 81kB 9.7MB/s
# Collecting flask-wtf<0.15,>=0.14.2 (from apache-airflow)
#   Downloading https://files.pythonhosted.org/packages/60/3a/58c629472d10539ae5167dc7c1fecfa95dd7d0b7864623931e3776438a24/Flask_WTF-0.14.2-py2.py3-none-any.whl
# Collecting pendulum==1.4.4 (from apache-airflow)
#   Downloading https://files.pythonhosted.org/packages/cc/ba/a7ef16485be134f0acec118b6b9036741d664cc0042c7d6e48c613ea9d88/pendulum-1.4.4-cp35-cp35m-manylinux1_x86_64.whl (123kB)
#     100% |████████████████████████████████| 133kB 8.3MB/s
# Collecting tzlocal>=1.4 (from apache-airflow)
#   Downloading https://files.pythonhosted.org/packages/cb/89/e3687d3ed99bc882793f82634e9824e62499fdfdc4b1ae39e211c5b05017/tzlocal-1.5.1.tar.gz
# Collecting thrift>=0.9.2 (from apache-airflow)
#   Downloading https://files.pythonhosted.org/packages/c6/b4/510617906f8e0c5660e7d96fbc5585113f83ad547a3989b80297ac72a74c/thrift-0.11.0.tar.gz (52kB)
#     100% |████████████████████████████████| 61kB 8.9MB/s
# Collecting flask-caching<1.4.0,>=1.3.3 (from apache-airflow)
#   Downloading https://files.pythonhosted.org/packages/88/f1/7bbd68a4d79eb53c33863a17926f14268749b897c8a77ab589f2e9117d47/Flask_Caching-1.3.3-py2.py3-none-any.whl
# Collecting croniter<0.4,>=0.3.17 (from apache-airflow)
#   Downloading https://files.pythonhosted.org/packages/c8/4c/04dea44f87b963d5c3f2bbc391e6c69d0a14aa896e35590be56213a04e4f/croniter-0.3.30-py2.py3-none-any.whl
# Collecting unicodecsv>=0.14.1 (from apache-airflow)
#   Downloading https://files.pythonhosted.org/packages/6f/a4/691ab63b17505a26096608cc309960b5a6bdf39e4ba1a793d5f9b1a53270/unicodecsv-0.14.1.tar.gz
# Collecting json-merge-patch==0.2 (from apache-airflow)
#   Downloading https://files.pythonhosted.org/packages/39/62/3b783faabac9a099877397d8f7a7cc862a03fbf9fb1b90d414ea7c6bb096/json-merge-patch-0.2.tar.gz
# Collecting tabulate<0.9,>=0.7.5 (from apache-airflow)
#   Downloading https://files.pythonhosted.org/packages/c2/fd/202954b3f0eb896c53b7b6f07390851b1fd2ca84aa95880d7ae4f434c4ac/tabulate-0.8.3.tar.gz (46kB)
#     100% |████████████████████████████████| 51kB 9.6MB/s
# Collecting zope.deprecation<5.0,>=4.0 (from apache-airflow)
#   Downloading https://files.pythonhosted.org/packages/f9/26/b935bbf9d27e898b87d80e7873a0200cebf239253d0afe7a59f82fe90fff/zope.deprecation-4.4.0-py2.py3-none-any.whl
# Collecting python-dateutil<3,>=2.3 (from apache-airflow)
#   Downloading https://files.pythonhosted.org/packages/41/17/c62faccbfbd163c7f57f3844689e3a78bae1f403648a6afb1d0866d87fbb/python_dateutil-2.8.0-py2.py3-none-any.whl (226kB)
#     100% |████████████████████████████████| 235kB 5.6MB/s
# Collecting werkzeug<0.15.0,>=0.14.1 (from apache-airflow)
#   Downloading https://files.pythonhosted.org/packages/20/c4/12e3e56473e52375aa29c4764e70d1b8f3efa6682bef8d0aae04fe335243/Werkzeug-0.14.1-py2.py3-none-any.whl (322kB)
#     100% |████████████████████████████████| 327kB 3.7MB/s
# Collecting setproctitle<2,>=1.1.8 (from apache-airflow)
#   Downloading https://files.pythonhosted.org/packages/5a/0d/dc0d2234aacba6cf1a729964383e3452c52096dc695581248b548786f2b3/setproctitle-1.1.10.tar.gz
# Collecting flask-login<0.5,>=0.3 (from apache-airflow)
#   Downloading https://files.pythonhosted.org/packages/c1/ff/bd9a4d2d81bf0c07d9e53e8cd3d675c56553719bbefd372df69bf1b3c1e4/Flask-Login-0.4.1.tar.gz
# Collecting requests<3,>=2.20.0 (from apache-airflow)
#   Downloading https://files.pythonhosted.org/packages/7d/e3/20f3d364d6c8e5d2353c72a67778eb189176f08e873c9900e10c0287b84b/requests-2.21.0-py2.py3-none-any.whl (57kB)
#     100% |████████████████████████████████| 61kB 5.8MB/s
# Collecting gunicorn<20.0,>=19.5.0 (from apache-airflow)
#   Downloading https://files.pythonhosted.org/packages/8c/da/b8dd8deb741bff556db53902d4706774c8e1e67265f69528c14c003644e6/gunicorn-19.9.0-py2.py3-none-any.whl (112kB)
#     100% |████████████████████████████████| 122kB 8.8MB/s
# Collecting psutil<6.0.0,>=4.2.0 (from apache-airflow)
#   Downloading https://files.pythonhosted.org/packages/c6/c1/beed5e4eaa1345901b595048fab1c85aee647ea0fc02d9e8bf9aceb81078/psutil-5.6.2.tar.gz (432kB)
#     100% |████████████████████████████████| 440kB 3.2MB/s
# Collecting flask-admin==1.5.3 (from apache-airflow)
#   Downloading https://files.pythonhosted.org/packages/c3/bc/4cb71a88d8b0d478ed7f46e7bba632e988daae5ae07ce5413a31acbe8166/Flask-Admin-1.5.3.tar.gz (1.7MB)
#     100% |████████████████████████████████| 1.7MB 829kB/s
# Collecting iso8601>=0.1.12 (from apache-airflow)
#   Downloading https://files.pythonhosted.org/packages/ef/57/7162609dab394d38bbc7077b7ba0a6f10fb09d8b7701ea56fa1edc0c4345/iso8601-0.1.12-py2.py3-none-any.whl
# Collecting pandas<1.0.0,>=0.17.1 (from apache-airflow)
#   Downloading https://files.pythonhosted.org/packages/74/24/0cdbf8907e1e3bc5a8da03345c23cbed7044330bb8f73bb12e711a640a00/pandas-0.24.2-cp35-cp35m-manylinux1_x86_64.whl (10.0MB)
#     100% |████████████████████████████████| 10.0MB 130kB/s
# Collecting dill<0.3,>=0.2.2 (from apache-airflow)
#   Downloading https://files.pythonhosted.org/packages/fe/42/bfe2e0857bc284cbe6a011d93f2a9ad58a22cb894461b199ae72cfef0f29/dill-0.2.9.tar.gz (150kB)
#     100% |████████████████████████████████| 153kB 8.2MB/s
# Collecting pygments<3.0,>=2.0.1 (from apache-airflow)
#   Downloading https://files.pythonhosted.org/packages/13/e5/6d710c9cf96c31ac82657bcfb441df328b22df8564d58d0c4cd62612674c/Pygments-2.3.1-py2.py3-none-any.whl (849kB)
#     100% |████████████████████████████████| 849kB 1.4MB/s
# Collecting gitpython>=2.0.2 (from apache-airflow)
#   Downloading https://files.pythonhosted.org/packages/fe/e5/fafe827507644c32d6dc553a1c435cdf882e0c28918a5bab29f7fbebfb70/GitPython-2.1.11-py2.py3-none-any.whl (448kB)
#     100% |████████████████████████████████| 450kB 2.9MB/s
# Collecting lxml>=4.0.0 (from apache-airflow)
#   Downloading https://files.pythonhosted.org/packages/5d/c9/39689d56ccb58e8212ca3c9ef68246bb481040cbd4d602295488ed13019b/lxml-4.3.3-cp35-cp35m-manylinux1_x86_64.whl (5.6MB)
#     100% |████████████████████████████████| 5.6MB 224kB/s
# Collecting click>=5.1 (from flask<2.0,>=1.0->apache-airflow)
#   Downloading https://files.pythonhosted.org/packages/fa/37/45185cb5abbc30d7257104c434fe0b07e5a195a6847506c074527aa599ec/Click-7.0-py2.py3-none-any.whl (81kB)
#     100% |████████████████████████████████| 81kB 10.2MB/s
# Collecting itsdangerous>=0.24 (from flask<2.0,>=1.0->apache-airflow)
#   Downloading https://files.pythonhosted.org/packages/76/ae/44b03b253d6fade317f32c24d100b3b35c2239807046a4c953c7b89fa49e/itsdangerous-1.1.0-py2.py3-none-any.whl
# Collecting six>=1.9.0 (from tenacity==4.12.0->apache-airflow)
#   Downloading https://files.pythonhosted.org/packages/73/fb/00a976f728d0d1fecfe898238ce23f502a721c0ac0ecfedb80e0d88c64e9/six-1.12.0-py2.py3-none-any.whl
# Collecting ordereddict (from funcsigs==1.0.0->apache-airflow)
#   Downloading https://files.pythonhosted.org/packages/53/25/ef88e8e45db141faa9598fbf7ad0062df8f50f881a36ed6a0073e1572126/ordereddict-1.1.tar.gz
# Collecting MarkupSafe>=0.23 (from jinja2<=2.10.0,>=2.7.3->apache-airflow)
#   Downloading https://files.pythonhosted.org/packages/6e/57/d40124076756c19ff2269678de7ae25a14ebbb3f6314eb5ce9477f191350/MarkupSafe-1.1.1-cp35-cp35m-manylinux1_x86_64.whl
# Collecting colorama<1,>=0.3.9 (from flask-appbuilder==1.12.3->apache-airflow)
#   Downloading https://files.pythonhosted.org/packages/4f/a6/728666f39bfff1719fc94c481890b2106837da9318031f71a8424b662e12/colorama-0.4.1-py2.py3-none-any.whl
# Collecting Flask-Babel<1,>=0.11.1 (from flask-appbuilder==1.12.3->apache-airflow)
#   Downloading https://files.pythonhosted.org/packages/82/b0/986b29938d4e8be7deb552ebfd1ef16c311276a59bcae10dec567a5b3d20/Flask-Babel-0.12.2.tar.gz (44kB)
#     100% |████████████████████████████████| 51kB 10.0MB/s
# Collecting Flask-OpenID<2,>=1.2.5 (from flask-appbuilder==1.12.3->apache-airflow)
#   Downloading https://files.pythonhosted.org/packages/d1/a2/9d1fba3287a65f81b9d1c09c4f7cb16f8ea4988b1bc97ffea0d60983338f/Flask-OpenID-1.2.5.tar.gz (43kB)
#     100% |████████████████████████████████| 51kB 9.5MB/s
# Collecting Flask-SQLAlchemy<3,>=2.3 (from flask-appbuilder==1.12.3->apache-airflow)
#   Downloading https://files.pythonhosted.org/packages/08/ca/582442cad71504a1514a2f053006c8bb128844133d6076a4df17117545fa/Flask_SQLAlchemy-2.4.0-py2.py3-none-any.whl
# Collecting PyYAML>=3.0 (from flask-swagger==0.2.13->apache-airflow)
#   Downloading https://files.pythonhosted.org/packages/9f/2c/9417b5c774792634834e730932745bc09a7d36754ca00acf1ccd1ac2594d/PyYAML-5.1.tar.gz (274kB)
#     100% |████████████████████████████████| 276kB 4.0MB/s
# Collecting setuptools (from python-daemon<2.2,>=2.1.1->apache-airflow)
#   Downloading https://files.pythonhosted.org/packages/ec/51/f45cea425fd5cb0b0380f5b0f048ebc1da5b417e48d304838c02d6288a1e/setuptools-41.0.1-py2.py3-none-any.whl (575kB)
#     100% |████████████████████████████████| 583kB 2.2MB/s
# Collecting docutils (from python-daemon<2.2,>=2.1.1->apache-airflow)
#   Downloading https://files.pythonhosted.org/packages/36/fa/08e9e6e0e3cbd1d362c3bbee8d01d0aedb2155c4ac112b19ef3cae8eed8d/docutils-0.14-py3-none-any.whl (543kB)
#     100% |████████████████████████████████| 552kB 2.4MB/s
# Collecting lockfile>=0.10 (from python-daemon<2.2,>=2.1.1->apache-airflow)
#   Downloading https://files.pythonhosted.org/packages/c8/22/9460e311f340cb62d26a38c419b1381b8593b0bb6b5d1f056938b086d362/lockfile-0.12.2-py2.py3-none-any.whl
# Collecting Mako (from alembic<1.0,>=0.9->apache-airflow)
#   Downloading https://files.pythonhosted.org/packages/a1/bb/f4e5c056e883915c37bb5fb6fab7f00a923c395674f83bfb45c9ecf836b6/Mako-1.0.9.tar.gz (459kB)
#     100% |████████████████████████████████| 460kB 2.7MB/s
# Collecting python-editor>=0.3 (from alembic<1.0,>=0.9->apache-airflow)
#   Downloading https://files.pythonhosted.org/packages/c6/d3/201fc3abe391bbae6606e6f1d598c15d367033332bd54352b12f35513717/python_editor-1.0.4-py3-none-any.whl
# Collecting WTForms (from flask-wtf<0.15,>=0.14.2->apache-airflow)
#   Downloading https://files.pythonhosted.org/packages/9f/c8/dac5dce9908df1d9d48ec0e26e2a250839fa36ea2c602cc4f85ccfeb5c65/WTForms-2.2.1-py2.py3-none-any.whl (166kB)
#     100% |████████████████████████████████| 174kB 6.9MB/s
# Collecting pytzdata>=2018.3.0.0 (from pendulum==1.4.4->apache-airflow)
#   Downloading https://files.pythonhosted.org/packages/a7/90/c9a148b4c98ccf88765ab7399debd38a33660109c9ba23706f560109b6e1/pytzdata-2019.1-py2.py3-none-any.whl (491kB)
#     100% |████████████████████████████████| 491kB 2.9MB/s
# Collecting pytz (from tzlocal>=1.4->apache-airflow)
#   Downloading https://files.pythonhosted.org/packages/3d/73/fe30c2daaaa0713420d0382b16fbb761409f532c56bdcc514bf7b6262bb6/pytz-2019.1-py2.py3-none-any.whl (510kB)
#     100% |████████████████████████████████| 512kB 2.6MB/s
# Collecting chardet<3.1.0,>=3.0.2 (from requests<3,>=2.20.0->apache-airflow)
#   Downloading https://files.pythonhosted.org/packages/bc/a9/01ffebfb562e4274b6487b4bb1ddec7ca55ec7510b22e4c51f14098443b8/chardet-3.0.4-py2.py3-none-any.whl (133kB)
#     100% |████████████████████████████████| 143kB 8.4MB/s
# Collecting certifi>=2017.4.17 (from requests<3,>=2.20.0->apache-airflow)
#   Downloading https://files.pythonhosted.org/packages/60/75/f692a584e85b7eaba0e03827b3d51f45f571c2e793dd731e598828d380aa/certifi-2019.3.9-py2.py3-none-any.whl (158kB)
#     100% |████████████████████████████████| 163kB 7.3MB/s
# Collecting idna<2.9,>=2.5 (from requests<3,>=2.20.0->apache-airflow)
#   Downloading https://files.pythonhosted.org/packages/14/2c/cd551d81dbe15200be1cf41cd03869a46fe7226e7450af7a6545bfc474c9/idna-2.8-py2.py3-none-any.whl (58kB)
#     100% |████████████████████████████████| 61kB 9.2MB/s
# Collecting urllib3<1.25,>=1.21.1 (from requests<3,>=2.20.0->apache-airflow)
#   Downloading https://files.pythonhosted.org/packages/df/1c/59cca3abf96f991f2ec3131a4ffe72ae3d9ea1f5894abe8a9c5e3c77cfee/urllib3-1.24.2-py2.py3-none-any.whl (131kB)
#     100% |████████████████████████████████| 133kB 6.4MB/s
# Collecting numpy>=1.12.0 (from pandas<1.0.0,>=0.17.1->apache-airflow)
#   Downloading https://files.pythonhosted.org/packages/f6/f3/cc6c6745347c1e997cc3e58390584a250b8e22b6dfc45414a7d69a3df016/numpy-1.16.3-cp35-cp35m-manylinux1_x86_64.whl (17.2MB)
#     100% |████████████████████████████████| 17.2MB 76kB/s
# Collecting gitdb2>=2.0.0 (from gitpython>=2.0.2->apache-airflow)
#   Downloading https://files.pythonhosted.org/packages/da/30/a407568aa8d8f25db817cf50121a958722f3fc5f87e3a6fba1f40c0633e3/gitdb2-2.0.5-py2.py3-none-any.whl (62kB)
#     100% |████████████████████████████████| 71kB 10.1MB/s
# Collecting Babel>=2.3 (from Flask-Babel<1,>=0.11.1->flask-appbuilder==1.12.3->apache-airflow)
#   Downloading https://files.pythonhosted.org/packages/b8/ad/c6f60602d3ee3d92fbed87675b6fb6a6f9a38c223343ababdb44ba201f10/Babel-2.6.0-py2.py3-none-any.whl (8.1MB)
#     100% |████████████████████████████████| 8.1MB 174kB/s
# Collecting python3-openid>=2.0 (from Flask-OpenID<2,>=1.2.5->flask-appbuilder==1.12.3->apache-airflow)
#   Downloading https://files.pythonhosted.org/packages/bd/de/52c5699f52dcee3037db587196dcaf63ffedf5fbeba3183afe9b21a3a89f/python3_openid-3.1.0-py3-none-any.whl (130kB)
#     100% |████████████████████████████████| 133kB 8.8MB/s
# Collecting smmap2>=2.0.0 (from gitdb2>=2.0.0->gitpython>=2.0.2->apache-airflow)
#   Downloading https://files.pythonhosted.org/packages/55/d2/866d45e3a121ee15a1dc013824d58072fd5c7799c9c34d01378eb262ca8f/smmap2-2.0.5-py2.py3-none-any.whl
# Collecting defusedxml (from python3-openid>=2.0->Flask-OpenID<2,>=1.2.5->flask-appbuilder==1.12.3->apache-airflow)
#   Downloading https://files.pythonhosted.org/packages/06/74/9b387472866358ebc08732de3da6dc48e44b0aacd2ddaa5cb85ab7e986a2/defusedxml-0.6.0-py2.py3-none-any.whl
# Building wheels for collected packages: flask-appbuilder, flask-swagger, future, alembic, sqlalchemy, tzlocal, thrift, unicodecsv, json-merge-patch, tabulate, setproctitle, flask-login, psutil, flask-admin, dill, ordereddict, Flask-Babel, Flask-OpenID, PyYAML, Mako
#   Running setup.py bdist_wheel for flask-appbuilder ... done
#   Stored in directory: /home/jupyter/.cache/pip/wheels/e0/15/a5/8d3b7b4c1ba14266957d03b5a5450ada340fa57d40b9824826
#   Running setup.py bdist_wheel for flask-swagger ... done
#   Stored in directory: /home/jupyter/.cache/pip/wheels/81/b7/f4/1b38146234576bec8e9275e8bc49387d33e6af2aaa17f0b099
#   Running setup.py bdist_wheel for future ... done
#   Stored in directory: /home/jupyter/.cache/pip/wheels/bf/c9/a3/c538d90ef17cf7823fa51fc701a7a7a910a80f6a405bf15b1a
#   Running setup.py bdist_wheel for alembic ... done
#   Stored in directory: /home/jupyter/.cache/pip/wheels/5a/98/f9/4aecdd767cddcbee88474401b27f52bf31c809e0334d6942ae
#   Running setup.py bdist_wheel for sqlalchemy ... done
#   Stored in directory: /home/jupyter/.cache/pip/wheels/2c/90/a7/3b40c6cc468abff357b38fd075429920bd0d313659d889cf8a
#   Running setup.py bdist_wheel for tzlocal ... done
#   Stored in directory: /home/jupyter/.cache/pip/wheels/15/ae/df/a67bf1ed84e9bf230187d36d8dcfd30072bea0236cb059ed91
#   Running setup.py bdist_wheel for thrift ... done
#   Stored in directory: /home/jupyter/.cache/pip/wheels/be/36/81/0f93ba89a1cb7887c91937948519840a72c0ffdd57cac0ae8f
#   Running setup.py bdist_wheel for unicodecsv ... done
#   Stored in directory: /home/jupyter/.cache/pip/wheels/a6/09/e9/e800279c98a0a8c94543f3de6c8a562f60e51363ed26e71283
#   Running setup.py bdist_wheel for json-merge-patch ... done
#   Stored in directory: /home/jupyter/.cache/pip/wheels/68/87/a4/14d13a1e45fc800f5d73256bb8444c503c3132df4b9b1c50f9
#   Running setup.py bdist_wheel for tabulate ... done
#   Stored in directory: /home/jupyter/.cache/pip/wheels/2b/67/89/414471314a2d15de625d184d8be6d38a03ae1e983dbda91e84
#   Running setup.py bdist_wheel for setproctitle ... done
#   Stored in directory: /home/jupyter/.cache/pip/wheels/e6/b1/a6/9719530228e258eba904501fef99d5d85c80d52bd8f14438a3
#   Running setup.py bdist_wheel for flask-login ... done
#   Stored in directory: /home/jupyter/.cache/pip/wheels/39/10/74/d68194e28d5f7a83de5f66e5b2deff5ccbb424fe45e6b0e927
#   Running setup.py bdist_wheel for psutil ... done
#   Stored in directory: /home/jupyter/.cache/pip/wheels/17/08/ec/22b464874958c3fc91e1a75748fae2220eb704a8b1035f9a03
#   Running setup.py bdist_wheel for flask-admin ... done
#   Stored in directory: /home/jupyter/.cache/pip/wheels/6f/ca/26/3dcc4b3286ed103ef9328b856221a9881188653c5d38ac73db
#   Running setup.py bdist_wheel for dill ... done
#   Stored in directory: /home/jupyter/.cache/pip/wheels/5b/d7/0f/e58eae695403de585269f4e4a94e0cd6ca60ec0c202936fa4a
#   Running setup.py bdist_wheel for ordereddict ... done
#   Stored in directory: /home/jupyter/.cache/pip/wheels/78/d3/a8/9f52c7a389a0ffba6f575a3886b5f7a55461fb6ec34aa5fd38
#   Running setup.py bdist_wheel for Flask-Babel ... done
#   Stored in directory: /home/jupyter/.cache/pip/wheels/6b/dd/6d/7fe366f67c9c4d510601f8263aa15532813bc120c0be1d0268
#   Running setup.py bdist_wheel for Flask-OpenID ... done
#   Stored in directory: /home/jupyter/.cache/pip/wheels/3b/1e/c0/b941aa1a5954f1acabbf1671a64e27adc359c0b0e74b16f8b4
#   Running setup.py bdist_wheel for PyYAML ... done
#   Stored in directory: /home/jupyter/.cache/pip/wheels/ad/56/bc/1522f864feb2a358ea6f1a92b4798d69ac783a28e80567a18b
#   Running setup.py bdist_wheel for Mako ... done
#   Stored in directory: /home/jupyter/.cache/pip/wheels/46/23/48/366f0d8b14d436e58ad0aef531b14af8d8beabeb2986704bd5
# Successfully built flask-appbuilder flask-swagger future alembic sqlalchemy tzlocal thrift unicodecsv json-merge-patch tabulate setproctitle flask-login psutil flask-admin dill ordereddict Flask-Babel Flask-OpenID PyYAML Mako
# Installing collected packages: MarkupSafe, jinja2, click, werkzeug, itsdangerous, flask, six, tenacity, ordereddict, funcsigs, configparser, colorama, pytz, Babel, Flask-Babel, flask-login, defusedxml, python3-openid, Flask-OpenID, sqlalchemy, Flask-SQLAlchemy, WTForms, flask-wtf, python-dateutil, flask-appbuilder, PyYAML, flask-swagger, future, setuptools, docutils, lockfile, python-daemon, text-unidecode, Mako, python-editor, alembic, markdown, tzlocal, pytzdata, pendulum, thrift, flask-caching, croniter, unicodecsv, json-merge-patch, tabulate, zope.deprecation, setproctitle, chardet, certifi, idna, urllib3, requests, gunicorn, psutil, flask-admin, iso8601, numpy, pandas, dill, pygments, smmap2, gitdb2, gitpython, lxml, apache-airflow
# Successfully installed Babel-2.6.0 Flask-Babel-0.12.2 Flask-OpenID-1.2.5 Flask-SQLAlchemy-2.4.0 Mako-1.0.9 MarkupSafe-1.1.1 PyYAML-5.1 WTForms-2.2.1 alembic-0.9.10 apache-airflow-1.10.3 certifi-2019.3.9 chardet-3.0.4 click-7.0 colorama-0.4.1 configparser-3.5.3 croniter-0.3.30 defusedxml-0.6.0 dill-0.2.9 docutils-0.14 flask-1.0.2 flask-admin-1.5.3 flask-appbuilder-1.12.3 flask-caching-1.3.3 flask-login-0.4.1 flask-swagger-0.2.13 flask-wtf-0.14.2 funcsigs-1.0.0 future-0.16.0 gitdb2-2.0.5 gitpython-2.1.11 gunicorn-19.9.0 idna-2.8 iso8601-0.1.12 itsdangerous-1.1.0 jinja2-2.10 json-merge-patch-0.2 lockfile-0.12.2 lxml-4.3.3 markdown-2.6.11 numpy-1.16.3 ordereddict-1.1 pandas-0.24.2 pendulum-1.4.4 psutil-5.6.2 pygments-2.3.1 python-daemon-2.1.2 python-dateutil-2.8.0 python-editor-1.0.4 python3-openid-3.1.0 pytz-2019.1 pytzdata-2019.1 requests-2.21.0 setproctitle-1.1.10 setuptools-41.0.1 six-1.12.0 smmap2-2.0.5 sqlalchemy-1.2.19 tabulate-0.8.3 tenacity-4.12.0 text-unidecode-1.2 thrift-0.11.0 tzlocal-1.5.1 unicodecsv-0.14.1 urllib3-1.24.2 werkzeug-0.14.1 zope.deprecation-4.4.0
# Note: you may need to restart the kernel to use updated packages.
